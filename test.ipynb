# %%
# !pwd
# Out:
# /tmp/working

# %%
# !ls
# Out:
# Dockerfile  README.md  docker-compose.yml  test.ipynb

# %%
# !pip list
# Out:
# Package                        Version             Location
# ------------------------------ ------------------- --------------
# absl-py                        0.12.0
# adal                           1.2.6
# affine                         2.3.0
# aiobotocore                    1.2.2
# aiohttp                        3.7.3
# aiohttp-cors                   0.7.0
# aioitertools                   0.7.1
# aioredis                       1.3.1
# albumentations                 0.5.2
# alembic                        1.5.8
# allennlp                       2.2.0
# altair                         4.1.0
# annoy                          1.17.0
# ansiwrap                       0.8.4
# appdirs                        1.4.4
# argon2-cffi                    20.1.0
# arrow                          0.17.0
# arviz                          0.11.2
# asn1crypto                     1.4.0
# astropy                        4.2
# astunparse                     1.6.3
# async-generator                1.10
# ...
